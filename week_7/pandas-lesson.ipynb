# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt

# %%
x  = np.array( [-10, -5, -4,-20,  -3, -2, -1, 0, 9, 1, 2,5,  3, 4, 5])
y = 2 * x

print(x)
print(y)
# Out:
# [-10  -5  -4 -20  -3  -2  -1   0   9   1   2   5   3   4   5]
# [-20 -10  -8 -40  -6  -4  -2   0  18   2   4  10   6   8  10]

# %%
plt.plot(x, y)
plt.show()

# %%
y = -2 * x

# %%
plt.plot(x, y)

# %%
y = x ** 2

# %%
plt.plot(x, y)

# %%
arr = np.array(lst)
print(arr)
# Out:
# [1 2 3 4 5]

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
np.array([1, 2, 3]) / 2
# Out:
# array([0.5, 1. , 1.5])

# %%
data = [19, 25, 30, 25, 19, 22, 45, 50, 65, 25, 20, 32, 59]
len(data)
# Out:
# 13

# %%
data = np.array(data)
data
# Out:
# array([19, 25, 30, 25, 19, 22, 45, 50, 65, 25, 20, 32, 59])

# %%
data.mean()
# Out:
# 33.53846153846154

# %%
data.std()
# Out:
# 15.224551955592018

# %%
data.std() ** 2
# Out:
# 231.78698224852073

# %%
data.var()
# Out:
# 231.78698224852073

# %%
# mean, median, mode, standard deviation, varience, percentile, range

# %%
import pandas as pd
url = 'https://restcountries.eu/rest/v2/all'
df = pd.read_json(url)

# %%
df.head(10)
# Out:
#                   name topLevelDomain alpha2Code alpha3Code callingCodes  \
# 0          Afghanistan          [.af]         AF        AFG         [93]
# 1        Åland Islands          [.ax]         AX        ALA        [358]
# 2              Albania          [.al]         AL        ALB        [355]
# 3              Algeria          [.dz]         DZ        DZA        [213]
# 4       American Samoa          [.as]         AS        ASM       [1684]
# 5              Andorra          [.ad]         AD        AND        [376]
# 6               Angola          [.ao]         AO        AGO        [244]
# 7             Anguilla          [.ai]         AI        AIA       [1264]
# 8           Antarctica          [.aq]         AQ        ATA        [672]
# 9  Antigua and Barbuda          [.ag]         AG        ATG       [1268]
#
#             capital                                       altSpellings  \
# 0             Kabul                                   [AF, Afġānistān]
# ...

# %%
df.columns
# Out:
# Index(['name', 'topLevelDomain', 'alpha2Code', 'alpha3Code', 'callingCodes',
#        'capital', 'altSpellings', 'region', 'subregion', 'population',
#        'latlng', 'demonym', 'area', 'gini', 'timezones', 'borders',
#        'nativeName', 'numericCode', 'currencies', 'languages', 'translations',
#        'flag', 'regionalBlocs', 'cioc'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 24

# %%
df['population']
# Out:
# 0      27657145
# 1         28875
# 2       2886026
# 3      40400000
# 4         57100
#          ...
# 245       11750
# 246      510713
# 247    27478000
# 248    15933883
# 249    14240168
# Name: population, Length: 250, dtype: int64

# %%
for language in df['languages']:
    print(language)
# Out:
# [{'iso639_1': 'ps', 'iso639_2': 'pus', 'name': 'Pashto', 'nativeName': 'پښتو'}, {'iso639_1': 'uz', 'iso639_2': 'uzb', 'name': 'Uzbek', 'nativeName': 'Oʻzbek'}, {'iso639_1': 'tk', 'iso639_2': 'tuk', 'name': 'Turkmen', 'nativeName': 'Türkmen'}]
# [{'iso639_1': 'sv', 'iso639_2': 'swe', 'name': 'Swedish', 'nativeName': 'svenska'}]
# [{'iso639_1': 'sq', 'iso639_2': 'sqi', 'name': 'Albanian', 'nativeName': 'Shqip'}]
# [{'iso639_1': 'ar', 'iso639_2': 'ara', 'name': 'Arabic', 'nativeName': 'العربية'}]
# [{'iso639_1': 'en', 'iso639_2': 'eng', 'name': 'English', 'nativeName': 'English'}, {'iso639_1': 'sm', 'iso639_2': 'smo', 'name': 'Samoan', 'nativeName': "gagana fa'a Samoa"}]
# [{'iso639_1': 'ca', 'iso639_2': 'cat', 'name': 'Catalan', 'nativeName': 'català'}]
# [{'iso639_1': 'pt', 'iso639_2': 'por', 'name': 'Portuguese', 'nativeName': 'Português'}]
# [{'iso639_1': 'en', 'iso639_2': 'eng', 'name': 'English', 'nativeName': 'English'}]
# ...
